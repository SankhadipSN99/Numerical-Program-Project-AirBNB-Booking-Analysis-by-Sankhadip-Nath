# %% [markdown]
# <a href="https://colab.research.google.com/github/SankhadipSN99/Numerical-Program-Project-AirBNB-Booking-Analysis-by-Sankhadip-Nath/blob/main/SANKHADIP_NATH__AirBNB_Booking_Analysis_Final_28Feb_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  AIRBNB BOOKING ANALYSIS

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**  Sankhadip Nath

# %% [markdown]
# # **Project Summary -**
#
# The Exploratory Data Analysis (EDA) of Airbnb booking analysis is a critical component of the overall project aimed at understanding the various factors that influence customer booking decisions on the Airbnb platform. The EDA will provide insights into the patterns and trends in the booking data and identify any underlying relationships between variables that may impact customer behavior.
#
# The EDA will begin with data collection from the Airbnb platform, including information on the listings, their availability, prices, and customer reviews. The data will then be cleaned to remove any missing, inconsistent, or irrelevant information. The next phase of the EDA will involve data analysis to uncover patterns and trends in customer behavior, such as the most popular listing types, the most sought-after amenities, and the factors that impact booking rates.
#
# Data visualization will be used to effectively communicate the insights and findings of the data analysis. A combination of graphs, charts, and maps will be used to showcase the trends and patterns in the data. This will help to identify areas of opportunity and highlight areas that require improvement.
#
# The final phase of the EDA will involve summarizing the findings and providing recommendations on how the insights can be leveraged to improve the customer experience and increase booking rates. This will include recommendations on optimizing pricing strategies, enhancing the listing descriptions, and improving the overall customer experience. The findings and recommendations will be presented in a comprehensive report, detailing the methodology, findings, and recommendations.
#
# In conclusion, the EDA of Airbnb booking analysis will provide valuable insights into the patterns and relationships in the booking data and inform the development of predictive models that can be used to optimize the platform. The EDA will play a crucial role in ensuring the success of the overall Airbnb booking analysis project by providing a foundation for further analysis and optimization. The insights and recommendations generated by the EDA will help to drive growth and success for the Airbnb platform and ensure its continued evolution and adaptation to changing customer needs and preferences.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**
# To explore and understand the patterns and trends in the Airbnb booking data and to identify any underlying relationships between variables that may impact customer booking decisions."
#
# This problem statement highlights the need to gain a deeper understanding of the underlying patterns and relationships in the Airbnb booking data. The objective of the EDA is to uncover any trends, patterns, or anomalies in the data that may have an impact on customer booking decisions.
#
# The EDA will be an important step in the overall Airbnb booking analysis project as it will help to identify areas of opportunity and highlight areas that require improvement. By conducting an in-depth analysis of the data, the EDA will provide insights into the factors that influence customer behavior and inform the development of predictive models that can be used to optimize the platform.
#
# Ultimately, the EDA will play a crucial role in ensuring the success of the Airbnb booking analysis project by providing a foundation for further analysis and optimization. By exploring and understanding the patterns and trends in the data, the project team will be better equipped to make informed decisions and to drive growth and success for the Airbnb platform.

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 📖 Objective:
#
# I have extensive experience with Airbnb Booking Analysis. Here I intend to concentrate solely on New York City.
#
# The investigation is mostly focused on the boroughs of Brooklyn, Manhattan, Queens, Staten Island, and the Bronx.
#
# This information includes information about the host, lodging prices, and reviews, among other things.
#
# With the use of exploratory data analysis, data wrangling, visualization, and other tools, we can extract a lot of information from the analysis.
#
# Explore and analyze the data to discover key understandings (not limited to these) such as : What can we learn about different hosts and areas? What can we learn from predictions? (ex: locations, prices, reviews, etc) Which hosts are the busiest and why? Is there any noticeable difference of traffic among different areas and what could be the reason for it?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Read the database file from mounted google drive into dataframe df
airbnb_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DATASET csv/Airbnb NYC 2019.csv")

# %% [markdown]
# ### Dataset First View

# %%
#Display first 5 rows of the dataframe to understand the information present in the database
airbnb_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# Here we can see the first 5 rows of the Airbnb dataset.

# %% [markdown]
# ##Dataset last view

# %%
#Display last 5 rows of the dataframe to understand the information present in the database
airbnb_df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# Here we can see the last 5 rows of the Airbnb dataset.

# %% [markdown]
# ### Dataset Rows & Columns count

# %% [markdown]
# # Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# Here we can see that the Dataset consists of 48895 rows and 16 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# Here we get information of all the columns present in the Airbnb dataset and their respective data type.

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
airbnb_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate values across all the rows and columns of the dataset.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
airbnb_df.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# Visualizing the missing values
airbnb_df.dropna(subset=['name','host_name','last_review','reviews_per_month'], axis = 0, inplace =True)
airbnb_df.shape
# Out:
# (38821, 16)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Airbnb hotel booking dataset consists of 48895 rows and 16 columns in total. Out of which some columns named ['name','host_name','last_review','reviews_per_month'] are having some NULL values which are either categorical or customer_specific in nature. So, We can't take the mean,median, mode etc. here in place of missing values. So, the best approach here was to remove all those rows where the values in respective columns are missing. After removing the missing values, final shape of my dataset is 38821 rows and 16 columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
airbnb_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.882100e+04  3.882100e+04  38821.000000  38821.000000  38821.000000
# mean   1.810081e+07  6.424582e+07     40.728129    -73.951149    142.332526
# std    1.069372e+07  7.589752e+07      0.054991      0.046693    196.994756
# min    2.539000e+03  2.438000e+03     40.506410    -74.244420      0.000000
# 25%    8.721444e+06  7.029525e+06     40.688640    -73.982460     69.000000
# 50%    1.887286e+07  2.837092e+07     40.721710    -73.954810    101.000000
# 75%    2.756746e+07  1.018905e+08     40.762990    -73.935020    170.000000
# max    3.645581e+07  2.738417e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    38821.000000       38821.000000       38821.000000
# mean         5.869220          29.290255           1.373229
# std         17.389026          48.182900           1.680328
# ...

# %% [markdown]
# From the dataset description chart we can find that the average price is 153, average minimum nights is 7,

# %% [markdown]
# ### Variables Description

# %% [markdown]
# About the data
# 48895 Row, 16 - Column
# Categorical data :
#
# host name, neighbourhood_group, neighbourhood, room_type
# Data Has int, float and object data type
# Id : It is unique for each bookings, numeric values, data is not repeatable .
#
# name : How is the room. Ex : Clean & quiet apt home by the park, this can be neglected.
#
# host_id : ID of the host, Data is repeatable, Numerical data .
#
# host_name : Name of the host. This column is neglected, Categorical data .
#
# neighbourhood_group : It is borough (a town that has its own goverment ). Brooklyn,Manhattan, Queens, Bronx, Staten Island .
# Neighbourhood: Place of the location inside neighborhood group.
#
# Latitude : Numerical values , Position of the location.
#
# Longitude :Numerical values , Position of the location.
#
# room_type : Private, Shared or Entire/Home, Categorical value.
#
# price : Cost of the room, Numerical value.
#
# minimum_nights : How many days compulsory to stay.
#
# number_of_reviews : Total number of review for this host
#
# last_review : Give information regarding last reviews is given in date.
#
# reviews_per_month : Total number of reviews / Days in months
#
# calculated_host_listings_count : The total number of apartments and bedrooms referred to the same landlord.
#
# availability_365 : Days it is available in a year

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
airbnb_df.nunique()
# Out:
# id                                38821
# name                              38253
# host_id                           30232
# host_name                          9885
# neighbourhood_group                   5
# neighbourhood                       218
# latitude                          17436
# longitude                         13639
# room_type                             3
# price                               581
# minimum_nights                       89
# number_of_reviews                   393
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# filling missing value using fillna()
airbnb_df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
airbnb_df_unique = df.drop_duplicates()
df_unique.shape
# Out:
# (48895, 16)

# %%
#duplicate row value delete
airbnb_df.drop_duplicates(inplace = True)

# %%
#understnading difference between host_name and host_id
#finding number of unique values in host name
airbnb_df['host_name'].nunique()
print('Number of unique values in host_name :', airbnb_df['host_name'].nunique())
# Out:
# Number of unique values in host_name : 11452

# %%
#length of unque values in host_id
airbnb_df['host_id'].nunique()
print('Number of unique values in host_id :', airbnb_df['host_id'].nunique())
# Out:
# Number of unique values in host_id : 37457

# %%
#host_name values count
airbnb_df['host_name'].value_counts()
# Out:
# Michael           335
# David             309
# John              250
# Alex              229
# Sonder (NYC)      207
#                  ...
# Krisztián           1
# Kila                1
# Maisha              1
# Martin & Hande      1
# Rusaa               1
# Name: host_name, Length: 9885, dtype: int64

# %%
#host_id values counts
airbnb_df['host_id'].value_counts()
# Out:
# 219517861    207
# 61391963      79
# 16098958      61
# 137358866     51
# 7503643       49
#             ...
# 6389984        1
# 68684053       1
# 60077920       1
# 9997184        1
# 74162901       1
# Name: host_id, Length: 30232, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Duplicate rows are deleted. Null values of all the rows are deleted as those could not be replaced due to lack of proper data. Here we can analyse that host_id will be same if same person hosted same propety at multiple times and also property name and host name is insignificant. so we can exclude them from the datasetAnswer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
# ##What can we learn about different hosts and areas?

# %%
# Chart - 1  visualization code
plt.style.use('classic')
sns.set_palette(['green', 'maroon'])
plt.figure(figsize=(13,7))
sns.scatterplot(data=airbnb_df, x="latitude", y='longitude', hue = 'neighbourhood_group', )
plt.title("Popularity based on location")
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ####1. Why did you pick the specific chart?
#
# Above scatter plot gives information of rooms hosted in different neighbourhood group as per their respective longitude and latitude.

# %% [markdown]
# ####2. What is/are the insight(s) found from the chart?
#
# From this it is clear that Queens and Brooklyn are the top places where highest number of property hosted in airbnb followed by Manhattan, Bronx and Staten Island.

# %% [markdown]
# #### Chart - 2
#
# #What kind of rooms are available highest and lowest in number ?

# %%
# Chart - 2 visualization code
#creating a count plot
plt.figure(figsize=(10,6))
plt.style.use('classic')
airbnb_df['room_type'].value_counts().plot(kind='bar', color= ['blue', 'red', 'green'])
#adding title,x and y labels to the plot
plt.ylabel('Number of rooms')
plt.xlabel('Type of rooms')
plt.title('Room Type Vs No. of Rooms')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get a clear visual about the quantity of each kind of room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# From the above bar chart we find that Entire home/apt is highest in number, private rooms are the second and very shared rooms are there.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Since people are prefering entire home and private rooms the most so I would suggest AirBNB to add much more such room types to their portal which will be definitely beneficial for them.

# %% [markdown]
# #### Chart - 3
#
# #What are the top 20 neighbourhood where people visited the most all over the NYC?

# %%
# Chart - 3 visualization code
#creating a count plot
#plotting bar chart for most visting place
#selecting top 20 neighbourhood where people visit
plt.figure(figsize=(16,13))
plt.style.use('classic')
df1 = {'count_of_neighbourhood' : airbnb_df['neighbourhood'].value_counts()}
neighbourhood = pd.DataFrame(df1)
top_20_neighbourhood = neighbourhood.sort_values('count_of_neighbourhood',ascending=False).head(20)
top_20_neighbourhood

top_20_neighbourhood.plot.bar(color = 'brown')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get a clear visual for the top 20 places all over the NYC where people visited the most.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the abobe chart we can see that Williamsburg followed by Bedford_Stuyvesant and Harlem are the top three visited places. So, hotel bookings are also the highest in those places.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this analysis it helps to understand which pleace is mostly visited by the people and So that if there is any properties present in this area then they will get regular customer and more profit.

# %% [markdown]
# #### Chart - 4
#
# #Who are the top 10 hosts having maximum number of host_id ?

# %%
# Chart - 4 visualization code
#top 10 host_name according to their number of host IDs
top_10_host = airbnb_df.groupby('host_name').agg({'host_id' : 'count'}).sort_values('host_id', ascending=False).head(10)
plt.figure(figsize=(14,8))
plt.style.use('classic')
top_10_host.plot.bar(color = 'blue')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get a clear visual of the top 10 Host names depending on their host_id numbers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we find that the top 3 host names are Michael, David & John respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# I suggest AirBNB to focus on those top Host_names to enlarge their businesses with them and gain much more profit as they have most of the host_id with them in all the popular visited places.

# %% [markdown]
# #### Chart - 5
# #Which are the top 10 visited places in each of the neighbouring groups?

# %%
# Chart - 5 visualization code
#storing all the diffrent neighbourhood groups to diffrent data frames
brooklyn_group_df=airbnb_df.loc[airbnb_df['neighbourhood_group']== 'Brooklyn']
manhattan_group_df=airbnb_df.loc[airbnb_df['neighbourhood_group']== 'Manhattan']
Queens_group_df=airbnb_df.loc[airbnb_df['neighbourhood_group']== 'Queens']
Staten_Island_group_df=airbnb_df.loc[airbnb_df['neighbourhood_group']== 'Staten Island']
Bronx_group_df=airbnb_df.loc[airbnb_df['neighbourhood_group']== 'Bronx']

# %%
# creating subplots to plot all the graphs together
fig, axes = plt.subplots(3,2, figsize=(42, 26))

plt.yticks(fontsize=40)
sns.countplot(ax=axes[0,0],y="neighbourhood", data=brooklyn_group_df, palette="icefire",
              order=brooklyn_group_df.neighbourhood.value_counts().iloc[:10].index).set_title('top 10 Brooklyn neighbourhood value count')

sns.countplot(ax=axes[0,1],y="neighbourhood", data=manhattan_group_df, palette="vlag",
              order=manhattan_group_df.neighbourhood.value_counts().iloc[:10].index).set_title('top 10 Manhattan neighbourhood value count')

sns.countplot(ax=axes[1,0],y="neighbourhood", data=Queens_group_df, palette="coolwarm",
              order=Queens_group_df.neighbourhood.value_counts().iloc[:10].index).set_title('top 10 Queens neighbourhood value count')

sns.countplot(ax=axes[1,1],y="neighbourhood", data=Staten_Island_group_df, palette="viridis",
              order=Staten_Island_group_df.neighbourhood.value_counts().iloc[:10].index).set_title('top 10 Staten_Island neighbourhood value count')

sns.countplot(ax=axes[2,0],y="neighbourhood", data=Bronx_group_df, palette="magma",
              order=Bronx_group_df.neighbourhood.value_counts().iloc[:10].index).set_title('top 10 Bronx neighbourhood value count')
# Out:
# <ipython-input-5-2228127b2b6f>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=axes[0,0],y="neighbourhood", data=brooklyn_group_df, palette="icefire",
# <ipython-input-5-2228127b2b6f>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=axes[0,1],y="neighbourhood", data=manhattan_group_df, palette="vlag",
# <ipython-input-5-2228127b2b6f>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=axes[1,0],y="neighbourhood", data=Queens_group_df, palette="coolwarm",
# <ipython-input-5-2228127b2b6f>:14: FutureWarning:
#
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The main motive to create this subplot is to get a clear visuals of the top 10 visited places specifically for all the neighbouring groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# The top 3 neighbouring places in Brooklyn are Williamsburg, Stuyvesant and Bushwick respectively.
#
#
# The top 3 neighbouring places in Manhattan are Harlem, Upper West Side and Hell's Kitchen respectively.
#
# The top 3 neighbouring places in Queens are Astoria, Long Island City and Flushing respectively.
#
# The top 3 neighbouring places in Staten_Island are St. George, Tompkinsville and Stapleton respectively.
#
# The top 3 neighbouring places in Bronx are Kingsbridge, Fordham and Longwood respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# AirBNB should focus more on the top most polpular locations which are most preferred by the people in each neighbouring groups. In this way, they can attain a higher gain in their business.

# %% [markdown]
# #### Chart - 6
# #What is the room availability acros all the NYC locations?

# %%
# Chart - 6 visualization code
#considering rows having availability_365 column values greater than zero(0) for availabilty of room
Room_available = airbnb_df[airbnb_df["availability_365"] > 0 ]

#box plot for availability room
plt.style.use('classic')
plt.figure(figsize=(13,7))
plt.title("Neighbourhood Group vs. Availability Room")
sns.boxplot(data=Room_available, x='neighbourhood_group',y='availability_365',palette="magma")
plt.show()
# Out:
# <ipython-input-13-74eb8c48d44a>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=Room_available, x='neighbourhood_group',y='availability_365',palette="magma")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The main objective of creating this boxplot is to get a clear idea of the rooms availability across the whole NYC location.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Mean of staten island room availability  is 250 days which is the higest. Manhattan, Queens and Bronx have roomavailabity equal to 160 days whereas Brooklyn has the lowest that is 150 days.
#  So we can say that Brooklyn is the top most visited place as room availability is the least here. Followed by Bronx,Queens, Manhattan and lastly Staten Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this analysis we got to know that although Broklyn and Manhattan has highest number of rooms but availabilty is very less htat is we can say that people often visit these places compared to Staten Island. So, for customers point of view they must do atleast 3 months prior booking unless they can find less available rooms.
#
#
# And in the Airbnb business point of view, we can say that they should do something that room availability in all the places can be increased very near to 365 days.

# %% [markdown]
# #### Chart - 7
#
# #What is the percentage of rooms available in the AirBNB portal for each of the neighbouring groups ?

# %%
# Chart - 7 visualization code
plt.style.use('fivethirtyeight')
plt.figure(figsize=(13,7))
plt.title("Neighbourhood Group")
plt.pie(airbnb_df.neighbourhood_group.value_counts(), labels= airbnb_df.neighbourhood_group.value_counts().index,autopct='%1.1f%%', startangle=180)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  To find the percentage of available room types in AirBNB portal for each of the individual neighbouring groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan(44.3%) is the highest property capturing area followed by Brooklyn(41.1%) and Queens(11.6%). These are the top three performing neighbouring areas in the AIRBNB portal lastly followed by Bronx and Staten Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this chart we can analyse the name of top performing neighbouring areas and this insight will help AIRBNB to focus on those locations more than eve as such places are top visited by the travellers.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
#Top10 neighbourhood listings for respective room types

#Top10 Entire home/apt neighbourhood
apt = airbnb_df[airbnb_df['room_type']=='Entire home/apt']
list_apt = apt.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name='apartment').sort_values(by=['apartment'],ascending=False)

#Top10 Private Room neighbourhood
private_room = airbnb_df[airbnb_df['room_type']=='Private room']
list_private_room = airbnb_df.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name = 'private_room').sort_values(by=['private_room'], ascending = False)

#Top10 Shared Room neighbourhood
shared_room = airbnb_df[airbnb_df['room_type']=='Shared room']
list_shared_room = airbnb_df.groupby(['host_id','host_name','neighbourhood','neighbourhood_group']).size().reset_index(name = 'shared_room').sort_values(by=['shared_room'], ascending = False)

#Creating subplots for creting visuals for all the room types
fig, axes = plt.subplots(2,2, figsize=(40, 15))
plt.yticks(fontsize=30)
plt.xticks(fontsize=20)
plt.style.use('classic')
sns.countplot(ax=axes[0,0],data = list_apt, y = 'neighbourhood', order = list_apt.neighbourhood.value_counts().iloc[0:10].index, palette = 'muted'
              ).set_title('Top 10 neighbourhood for Entire Room/apt')

sns.countplot(ax=axes[0,1],data = list_private_room, y = 'neighbourhood', order = list_private_room.neighbourhood.value_counts().iloc[0:10].index, palette = 'icefire'
              ).set_title('Top 10 neighbourhood for Private Room')

sns.countplot(ax=axes[1,0],data = list_shared_room, y = 'neighbourhood', order = list_shared_room.neighbourhood.value_counts().iloc[0:10].index, palette = 'rainbow'
              ).set_title('Top 10 neighbourhood for Shared Room')
# Out:
# <ipython-input-6-4039d925370d>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=axes[0,0],data = list_apt, y = 'neighbourhood', order = list_apt.neighbourhood.value_counts().iloc[0:10].index, palette = 'muted'
# <ipython-input-6-4039d925370d>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(ax=axes[0,1],data = list_private_room, y = 'neighbourhood', order = list_private_room.neighbourhood.value_counts().iloc[0:10].index, palette = 'icefire'
# <ipython-input-6-4039d925370d>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# I have adopted those bar charts to get the names of top 10 neighbourhood respectively for the various room types like Entire room/apt, Private room and Shared rooms.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# This chart shows us the names of top 10 neighbourhood for each room type which are the most popular among the people visiting AIRBNB hotel booking website.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# The insights we get from the visual will help Airbnb to make those top performing neighbourhood for the customers keeping them consumer friendly to live and spend their memorable times.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
#Top15 expensive neighbourhood place according to average price
plt.figure(figsize=(20,8))
plt.style.use('classic')
costly_place = airbnb_df.groupby('neighbourhood').agg({'price' : 'mean'}).sort_values(by=['price'], ascending = False)
Top15_costly_df = costly_place.head(15)
Top15_costly_df.plot(kind = 'barh', color = ['brown'])
plt.xlabel('Average Price')
plt.ylabel('Neighbourhood')
plt.title('Top 15 Expensive Neighbourhood as per Average Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# This chart mainly gives us the idea about the top 15 premium quality or expensive neighbouring places. Airbnb business can have very clear idea about the named places and they can also improve their business over there.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# Here we find the top most 3 premium neighbouring places are Fort Wadsworth, Woodrow and Tribeca.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Yes, this insight is definitely helpful for the Airbnb business as they can focus more on those places for their premium class customers and also can guide the targeted customers offering the above mentioned neighbouring places to provide them with top notch service.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#Top15 cheapest neighbourhood place according to average price
plt.figure(figsize=(20,8))
plt.style.use('classic')
cheap_place = airbnb_df.groupby('neighbourhood').agg({'price' : 'mean'}).sort_values(by=['price'], ascending = True)
Top15_cheap_df = cheap_place.head(15)
Top15_cheap_df.plot(kind = 'barh', color = ['blue'])
plt.xlabel('Average Price')
plt.ylabel('Neighbourhood')
plt.title('Top 15 Cheapest Neighbourhood as per Average Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Since, the Neighbourhood is a categorical data, so to get visuals about finding the top 15 cheapest properties I have adopted the Bar chart here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The above chart is helpful to get insights about the top 15 cheapest neighbourhood among all the places available in the Airbnb portal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# From the above chart we see that the top 3 cheapest properties are Bull's head, Hunts Point and Tremont. Such a data is very helpful to the Sirbnb business because the customers who are looking for cheapest places to live, they can be easily guided in the same way using this insights.

# %% [markdown]
# #### Chart - 11
# ##What are the top 15 most listed places ?

# %%
# Chart - 11 visualization code
sns.set_palette('magma')
plt.figure(figsize=(15,7))
most_listed_df= airbnb_df[['host_name','neighbourhood']].groupby('neighbourhood').agg({'host_name': 'count'})
Top15_most_listed_df= most_listed_df.sort_values(by='host_name', ascending = False).head(15)
Top15_most_listed_df.plot(kind='barh')
plt.xlabel('Neighbourhood')
plt.ylabel('Listing count')
plt.title('Top 15 Most Listed Places')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As we are trying to find the top 15 listed neighbourhood places, and neighbourhood place is a categorical data. So it's quite easy to visualise the same with a Bar Chart that is why I have adopted this chart here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we find the top 15 neighbouring places out of which top five are Williamsburg, Bedford_Stuyvesant, Harlem, Bushwick and Upper Westside respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The places which lies among top five neighbourhood places should be promoted in the Airbnb portal on a priority basis, apart from that they also need to work on the other neighbourhood places which have less number of hosts available and they need to increase the number.

# %% [markdown]
# #### Chart - 12
# ##What are to 15 least listed places?

# %%
# Chart - 12 visualization code
sns.set_palette('rainbow')
plt.figure(figsize=(15,7))
least_listed_df= airbnb_df[['host_name','neighbourhood']].groupby('neighbourhood').agg({'host_name': 'count'})
Top15_least_listed_df= least_listed_df.sort_values(by='host_name', ascending = True).head(15)
Top15_least_listed_df.plot(kind='barh')
plt.xlabel('Neighbourhood')
plt.ylabel('Listing count')
plt.title('Least Most 15 Listed Places')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As we are trying to find the least 15 listed neighbourhood places, and neighbourhood place is a categorical data. So it's quite easy to visualise the same with a Bar Chart that is why I have adopted this chart here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we find the  15 least neighbouring places in terms of host_names available out of which leastmost  five are Rossville, Richmondtown, Fort Wadsworth, Willowbrook and New Drop.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Airbnb business should take this insights on a priority basis and they need to increase the number of hosts availability at those places. As it would be beneficial for their business growth.

# %% [markdown]
# #### Chart - 13
# ##What are the top most popular place accourding to customer reviews ?

# %%
popular_place.head(15).plot(kind= 'bar', color = ['r', 'b', 'g', 'y', 'm'])

# %%
# Chart - 13 visualization code
review_50 = airbnb_df[airbnb_df['number_of_reviews']>=50]
popular_place = airbnb_df[['neighbourhood_group', 'number_of_reviews']].groupby('neighbourhood_group').agg({'number_of_reviews' : 'count'}).sort_values(by='number_of_reviews', ascending = False)
popular_place.rename(columns = {'number_of_reviews' : 'review_count'}, inplace = True)
popular_place.head(15).plot(kind= 'bar', color = ['r', 'b', 'g', 'y', 'm'])
plt.xlabel('Neighbourhood_group')
plt.ylabel('Review_count')
plt.title('Neighbourhood_group VS Review Count(Min of 50)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As we are trying to find the popularity of Neighbourhood_groups in terms of the respective review counts. So, again it's a categorical data. So the best suited chart I'm using here is the Bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here in this bar chart we find that Manhattan is the top engaging neighbourhood group in terms of review counts followed by Brooklyn, Queens, Bronx and Staten Island respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As we find the top engaging neighbouring areas are Manhattan, Brooklyn and Queens respectively. These locations have a promising number of engagement but
# there is a concern with Bronx and Staten Island. So, Airbnb should promote these two locations as well in terms of tourism and also look into the matter of servicability, the quality of rooms available everything. If they can modify these key points, I am sure they would earn some fruitful revenue from those locations of Bronx and Staten Island as well.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
plt.style.use('classic')
heatmap_df = airbnb_df[['price','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']]
heatmap_df.corr()
sns.heatmap(heatmap_df.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# ## **I have mainly adopted this Heatmap Chart to get visuals about all the numerical columns available in the Aribnb Dataset, the correlation between all those columns either it's positive or negative correlation. This Heatmap helps us to predict some future aspects in order to the business aspects.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Top 3 correlation columns:**
#
# #The number_of_reviews and reviews per_month columns has highest correlation of values is 0.55.
#
# #The calculated_host_listings_count and availability_365 columns second highest correlation of values is 0.23
#
# #The reviews_per_month and availability_365 columns second highest correlation of values is 0.19

# %% [markdown]
# #### Chart - 15 - Histogram

# %%
sns.set_palette('dark')
plt.figure(figsize = (12,8))
sns.scatterplot(data = airbnb_df, x = 'number_of_reviews', y = 'reviews_per_month', hue= 'room_type')
sns.lineplot(data = airbnb_df, x = 'number_of_reviews', y = 'reviews_per_month', hue= 'room_type')
sns.histplot(data = airbnb_df, x ='number_of_reviews',hue= 'room_type', kde = True)
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The main objective of mine here is to get the ditribution of number_of _reviews with respect to monthly review counts among all the room types. As we are trying to show the distribution of the reviews among all the room types , we have adopted the Histogram chart here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart, we can find that Private rooms have the highest distribution among all the room types, followed by Entire home/apt and lastly the shared rooms.
# So from this insights we can say that most of the visitors prefer the Private Rooms and Entire homes. It means Airbnb needs to focus a lot on improving the service quality and maintenance of those living places.
#
#
# But, they should also focu on shared rooms category and betterment of the quality to increase the travellers' enegagement in those properties also.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
#
#
# Based on the analysis of Airbnb booking data, there are several recommendations that could help the client achieve their business objectives:
#
# Improve the quality of listings: As we found that there is a positive correlation between the number of reviews and the booking price, it is important for the client to focus on improving the quality of listings on their platform. They could provide more resources and guidance to hosts to help them create more attractive and high-quality listings.
#
# Focus on popular neighborhoods: As Manhattan and Queens were found to be the most popular neighborhoods, the client could focus on acquiring more listings in these areas and improving the quality of existing listings. This could help increase bookings and revenue for the client.
#
# Optimize pricing strategy: Based on the booking patterns and preferences of users, the client could optimize their pricing strategy to reflect the demand for different types of rooms and neighborhoods. They could use dynamic pricing to adjust prices during peak times and maximize revenue.
#
# Improve user experience: To provide a better experience for their guests, the client could consider investing in technology and tools to improve the booking process and communication between hosts and guests. They could also provide more personalized recommendations to guests based on their preferences and booking history.
#
# Expand to new markets: The client could consider expanding their platform to new markets or neighborhoods that are currently underserved by Airbnb. This could help them attract new hosts and guests and increase their revenue and market share.
#
# Overall, by focusing on these recommendations, the client can achieve their business objectives of increasing bookings, revenue, and user satisfaction.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the analysis of Airbnb booking data provides valuable insights into the booking patterns and preferences of users. Through the analysis of various variables such as the type of room, neighborhood, and pricing, we can identify trends and patterns that can help Airbnb optimize their business strategy and provide a better experience for their users.
#
# We found that entire apartments were the most popular type of room booked by guests, followed by private rooms and shared rooms. Additionally, we found that Manhattan and Queens were the most popular neighborhoods, with the highest number of listings per host. We also discovered that there was a positive correlation between the number of reviews and the booking price, suggesting that guests were willing to pay more for higher-quality listings.
#
# Overall, this analysis provides valuable insights into the Airbnb platform and can help the company make data-driven decisions to optimize their business strategy and improve the user experience. By understanding the booking preferences of users, Airbnb can prioritize their efforts and resources to maximize revenue and provide a better experience for their hosts and guests.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
